# %% [markdown]
# # INCLASS NOTEBOOK - DAY04

# %% [markdown]
# ## ---------------------------- Visualization: Seaborn and matplotlib -----------------------------------

# %% [markdown]
#  **Package/Libraries** - Matplotlib
#
# **Matplotlib for Python Data Visualization**:-
#
# Matplotlib is oldest and most widely used pythonvisualization package, its a decade old its the first name come to our mind when it comes to plotting. Many libraries are built on top of it, and uses its functions in the backend. Its style is very simple and thats the reason plotting is fast in this. It is used to create axis and design the layout for plotting using other libraries like seaborn.

# %% [markdown]
# ---------------------------

# %% [markdown]
# **Package/Libraries** - Seaborn
#
# **Seaborn for Python Data Visualization**:-
#
# Seaborn Python is a data visualization library based on Matplotlib. It provides a high-level interface for drawing attractive statistical graphics. Because seaborn python is built on top of Matplotlib, the graphics can be further tweaked using Matplotlib tools and rendered with any of the Matplotlib backends to generate publication-quality figures

# %% [markdown]
# -----------------------

# %% [markdown]
# ## Calling libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Line Plot
#
# **what is the purpose of line plot and where it can be used.**
#
# A line graph is commonly used to display change over time as a series of data points connected by straight line segments on two axes. The line graph therefore helps to determine the relationship between two sets of values, with one data set always being dependent on the other set.

# %%
x = np.linspace(0, 1, 100)
y1 = np.sin(x*np.pi*2)
y2 = np.cos(x*np.pi*2)
y3 = np.tan(x**2)
plt.subplot(311)#3x1 plots
plt.legend()

plt.plot(x,y1,'ro',label="sin wave")#Plot red color circles
plt.legend()
plt.subplot(312)#3x1 plots
plt.plot(x,y3,'b--')#Plot blue with dotted line
plt.xlabel('Time')
plt.ylabel('Y Axis')
plt.title('Trignometric graphs')
plt.axis([0,1,-1,2])
plt.subplot(313)#3x1 plots
plt.bar(x[:10],y2[:10])
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = np.linspace(0, 1, 100)
y1 = np.sin(x*np.pi*2)
y2 = np.cos(x*np.pi*2)
y3 = np.tan(x**2)

plt.figure()
plt.plot(x,y1,'ro',label="sin wave")
plt.plot(x,y3,'b--', label="cos wave")
plt.legend()
plt.xlabel('Time')
plt.xticks()
plt.yticks()
plt.ylabel('Y Axis')
plt.axis([0,1,-1,2])#[xmin xmax ymin ymax]
plt.plot(x,y2,"^")

# %% [markdown]
# we can observe from above graph/plot for every increase in 'x' there is an increase in 'y',because 'y' is an `square` of 'x'

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(x,y)

# %% [markdown]
# As per our Above plot we interpret that as increase in 'x' there is an increase in 'y',Hence 'y' is an square of 'x''

# %% [markdown]
# ## Now Let us plot various visualisation plots using `seaborn` and `Matplot` libraries For the Given below dataset.

# %% [markdown]
# # House Prices Analysis

# %% [markdown]
# ## Reading in data

# %%
df_train = pd.read_csv('/Users/kamalmukiri/Documents/AptComputingAcademy/DataScience/Pandas/Data/house-predict-nn/data/house_train.csv')
auto = pd.read_csv("/Users/kamalmukiri/Documents/AptComputingAcademy/DataScience/Pandas/Data/Automobile.csv")

# %% [markdown]
# **Here's a brief version of what you'll find in the data description file.**
#
# **SalePrice** - the property's sale price in dollars. This is the target variable that you're trying to predict.
#
# **MSSubClass**: The building class
#
# **MSZoning**: The general zoning classification
#
# **LotFrontage**: Linear feet of street connected to property
#
# **LotArea**: Lot size in square feet
#
# **Street**: Type of road access
#
# **Alley**: Type of alley access
#
# **LotShape**: General shape of property
#
# **LandContour**: Flatness of the property
#
# **Utilities**: Type of utilities available
#
# **LotConfig**: Lot configuration
#
# **LandSlope**: Slope of property
#
# **Neighborhood**: Physical locations within Ames city limits
#
# **Condition1**: Proximity to main road or railroad
#
# **Condition2**: Proximity to main road or railroad (if a second is present)
#
# **BldgType**: Type of dwelling
#
# **HouseStyle**: Style of dwelling
#
# **OverallQual**: Overall material and finish quality
#
# **OverallCond**: Overall condition rating
#
# **YearBuilt**: Original construction date
#
# **YearRemodAdd**: Remodel date
#
# **RoofStyle**: Type of roof
#
# **RoofMatl**: Roof material
#
# **Exterior1st**: Exterior covering on house
#
# **Exterior2nd**: Exterior covering on house (if more than one material)
#
# **MasVnrType**: Masonry veneer type
#
# **MasVnrArea**: Masonry veneer area in square feet
#
# **ExterQual**: Exterior material quality
#
# **ExterCond**: Present condition of the material on the exterior
#
# **Foundation**: Type of foundation
#
# **BsmtQual**: Height of the basement
#
# **BsmtCond**: General condition of the basement
#
# **BsmtExposure**: Walkout or garden level basement walls
#
# **BsmtFinType1**: Quality of basement finished area
#
# **BsmtFinSF1**: Type 1 finished square feet
#
# **BsmtFinType2**: Quality of second finished area (if present)
#
# **BsmtFinSF2**: Type 2 finished square feet
#
# **BsmtUnfSF**: Unfinished square feet of basement area
#
# **TotalBsmtSF**: Total square feet of basement area
#
# **Heating**: Type of heating
#
# **HeatingQC**: Heating quality and condition
#
# **CentralAir**: Central air conditioning
#
# **Electrical**: Electrical system
#
# **1stFlrSF**: First Floor square feet
#
# **2ndFlrSF**: Second floor square feet
#
# **LowQualFinSF**: Low quality finished square feet (all floors)
#
# **GrLivArea**: Above grade (ground) living area square feet
#
# **BsmtFullBath**: Basement full bathrooms
#
# **BsmtHalfBath**: Basement half bathrooms
#
# **FullBath**: Full bathrooms above grade
#
# **HalfBath**: Half baths above grade
#
# **Bedroom**: Number of bedrooms above basement level
#
# **Kitchen**: Number of kitchens
#
# **KitchenQual**: Kitchen quality
#
# **TotRmsAbvGrd**: Total rooms above grade (does not include bathrooms)
#
# **Functional**: Home functionality rating
#
# **Fireplaces**: Number of fireplaces
#
# **FireplaceQu**: Fireplace quality
#
# **GarageType**: Garage location
#
# **GarageYrBlt**: Year garage was built
#
# **GarageFinish**: Interior finish of the garage
#
# **GarageCars**: Size of garage in car capacity
#
# **GarageArea**: Size of garage in square feet
#
# **GarageQual**: Garage quality
#
# **GarageCond**: Garage condition
#
# **PavedDrive**: Paved driveway
#
# **WoodDeckSF**: Wood deck area in square feet
#
# **OpenPorchSF**: Open porch area in square feet
#
# **EnclosedPorch**: Enclosed porch area in square feet
#
# **3SsnPorch**: Three season porch area in square feet
#
# **ScreenPorch**: Screen porch area in square feet
#
# **PoolArea**: Pool area in square feet
#
# **PoolQC**: Pool quality
#
# **Fence**: Fence quality
#
# **MiscFeature**: Miscellaneous feature not covered in other categories
#
# **MiscVal**: Value of miscellaneous feature
#
# **MoSold**: Month Sold
#
# **YrSold**: Year Sold
#
# **SaleType**: Type of sale
#
# **SaleCondition**: Condition of sale

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
df_train.head()
print(df_train.shape)
# Out:
# (1460, 81)

# %% [markdown]
# ## Looking at the number of rows and columns using shape function¶

# %%
df_train.shape  # this retrive number of rows,columns
# Out:
# (1460, 81)

# %%
plt.figure()
auto.make[:20].value_counts().plot(kind="pie",shadow=True)
plt.figure()
auto.body_style.value_counts().plot(kind='bar',color='Green')  

#plt.plot(auto.engine_size, auto.mpg)
print(auto.make[:20].value_counts())
print(type(auto.make[:20].value_counts()))
# Out:
# bmw            8
# audi           6
# chevrolet      3
# alfa-romero    3
# Name: make, dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Bar Plot
# **When to use:** If you have comparative data that you would like to represent through a chart then a bar chart would be the best option. This type of chart is one of the more familiar options as it is easy to interpret. These charts are useful for displaying data that is classified into nominal or odinal categories.

# %%
# visualize counts
print(df_train.SaleCondition.value_counts())
df_train.SaleCondition.value_counts().plot(kind='bar',color='Green')  
# plt.title('House Sale As per There Condition')
#df_train['BldgType'].value_counts().plot(kind='pie')       
print(df_train['BldgType'].value_counts())

# plt.ylabel('Counts')
# plt.xlabel('Conditions of houses ')
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: BldgType, dtype: int64

# %% [markdown]
# We can intrepret from the above plot or graph that the houses which are saled are mostly of Normal Conditioned houses.

# %% [markdown]
# ## Pie Plot
# **when to use pie plot** :- A pie chart is best used when trying to work out the composition of something. If you have categorical data then using a pie chart would work really well as each slice can represent a different category.

# %%
df_train['BldgType'].value_counts().plot(kind='pie')        
plt.title('Type of Building')
# Out:
# Text(0.5, 1.0, 'Type of Building')

# %% [markdown]
# we can observe or intrepret from the above pie plot that many buildings constructions where carried out for an 1 family oriented type.

# %% [markdown]
# ## Histogram plot
# **When to use** :- A histogram is a great tool for quickly assessing a `probability distribution` that is intuitively understood by almost any audience. Python offers a handful of different options for building and plotting histograms. Most people know a histogram by its graphical representation, which is similar to a bar graph:
#
# **Y-axis - Counts**
#
# **X-axis - Continous Variable**

# %%
plt.hist(df_train.SalePrice,bins=100,color='g')
plt.show()

plt.hist(df_train.SalePrice,bins=10,color='b')
plt.show()

# %%
plt.hist([df_train.SalePrice,df_train.SalePrice],bins=10,color=['g',"r"])
plt.show()

# %% [markdown]
#  From the above Plot or graph we intrepret that most of the customer who has purchased houses for the sales price mostly ranging between `11-12`.

# %% [markdown]
# ## Box plot
# **what is an boxplot:**
#
# **---** A Box Plot is the visual representation of the statistical five number summary of a given data set.
#
# Box and whisker plots have been used steadily since their introduction in 1969 and are varied in both their potential visualizations as well as use cases across many disciplines in statistics and data analysis.
#
# **A Five Number Summary includes:-**
#
# **Minimum** - Lowest value/record in that attribute/column .
#
# **First Quartile** -25TH Percentile
#
# **Median (Second Quartile)** - Middle value/record in that attribute/column .
#
# **Third Quartile** - 75TH Percentile
#
# **Maximum** - Lowest value/record in that attribute/column .
#
#
#
# **For example** in the number set where x = 1, 2, 3, 5, 6, 9, 10, 11, 12, 13
#
# The  **Five Number Summary** would be this:
#
# 13 - **MAX**
#
# 10.75 - **Q3**
#
# 7.5 - **MEDIAN**
#
# 3.5 - **Q1**
#
# 1 - **MIN**

# %%
plt.boxplot(df_train.SalePrice,vert=False)
print(df_train.SalePrice.describe())
print(df_train.SalePrice.min())
plt.figure()
plt.plot(df_train.SaleCondition, df_train.SalePrice, ".")
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64
# 34900

# %%
A_Vals=[1.26, 0.34, 0.70, 1.75, 50.57, 1.55, 0.08, 0.42, 0.50, 3.20, 0.15, 0.49, 0.95, 0.24, 1.37, 0.17, 6.98, 0.10, 0.94, 0.38]

B_Values= [2.37, 2.16, 14.82, 1.73, 41.04, 0.23, 1.32, 2.91, 39.41, 0.11, 27.44, 4.51, 0.51, 4.50, 0.18, 14.68, 4.66, 1.30, 2.06, 1.19]

df1 = pd.DataFrame(data = {"A":A_Vals, "B":B_Values})
plt.figure()
plt.boxplot([df1.A,df1.B], vert=False, labels=["A","B"])
plt.legend()

df1.plot()
plt.boxplot

df1.describe()
# Out:
# No handles with labels found to put in legend.
#                A          B
# count  20.000000  20.000000
# mean    3.607000   8.356500
# std    11.164638  12.819383
# min     0.080000   0.110000
# 25%     0.315000   1.272500
# 50%     0.600000   2.265000
# 75%     1.415000   7.165000
# max    50.570000  41.040000

# %%
df_train.boxplot('SalePrice','SaleCondition');                   #shows the distribution of values in the respective attribute

# %%
B_Values= [2.37, 2.16, 14.82, 1.73, 41.04, 0.23, 1.32, 2.91, 39.41, 0.11, 27.44, 4.51, 0.51, 4.50, 0.18, 14.68, 4.66, 1.30, 2.06, 1.19]
plt.boxplot(B_Values)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a237edc18>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a237ed7b8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a237edac8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a237e3588>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a237bac50>],
#  'means': []}

# %% [markdown]
# we can observe from above plot that in normal,abnormal condition houses we have few records/sale price are high priced than normal for that respective salecondition

# %% [markdown]
# ## scatter plot.
# **What is scatter plot** :-  A scatter plot is a two-dimensional data visualization that uses dots to represent the values obtained for two different variables - one plotted along the x-axis and the other plotted along the y-axis.
#
# **Where to use scatter plot** :-Scatter plots are used when you want to show the relationship between two variables. Scatter plots are sometimes called correlation plots because they show how two variables are correlated

# %%
df_train.plot.scatter(x='YrSold', y='SalePrice', color='r', title='scatter plot : Year of sold vs Salesprice');

# %% [markdown]
# From the above plot we can intrepret that the sales price for the houses doesn't much vary from year to year except for few houses which are high priced else low priced than normal prices.

# %% [markdown]
# ## Density Plot
#
# **What is the purpose of density plot/ kde-kernal density plot and where to be used** :-A Density Plot visualises the distribution of data over a continuous interval or time period. This chart is a variation of a Histogram that uses kernel smoothing to plot values, allowing for smoother distributions by smoothing out the noise. The peaks of a Density Plot help display where values are concentrated over the interval.
#
#
#
#
# **An advantage Density Plots have over Histograms** :- is that they're better at determining the distribution shape because they're not affected by the number of bins used (each bar used in a typical histogram). A Histogram comprising of only 4 bins wouldn't produce a distinguishable enough shape of distribution as a 20-bin Histogram would. However, with Density Plots, this isn't an issue.

# %%
df_train.SalePrice.plot(kind='kde', title='Density plot for salesprice', color='gold');
plt.show()

# %% [markdown]
# As seen early in histogram we can configure the same from kde plot that mostly saled price of houses is around 11.8 to 11.9

# %% [markdown]
# ## Area plot
#
# **what is the purpose of Area plot** :-An area chart is a good way to demonstrate trends over time to the viewer,This  chart is based on the line chart. The filled area can give a greater sense of the trends in a particular dataset.

# %%
print(df_train['YearBuilt'].head())
print(df_train['YearBuilt'].value_counts().count())
print(df_train['YearBuilt'].head())

#print(df_train['YearBuilt'].value_counts().sort_index())

df_train['YearBuilt'].value_counts().sort_index().plot.area()   #shows the area of no.of houses built in that respective year.
# Out:
# 0    2003
# 1    1976
# 2    2001
# 3    1915
# 4    2000
# Name: YearBuilt, dtype: int64
# 112
# 0    2003
# 1    1976
# 2    2001
# 3    1915
# 4    2000
# Name: YearBuilt, dtype: int64

# %% [markdown]
# we can observe from the plot that houses built are highest in the year 2000.

# %% [markdown]
# ----------------------

# %% [markdown]
# ## Lets plot the same Boxplot with a default seaborn style

# %%
sns.boxplot(data=df_train.SalePrice,color='gold')
plt.show()

# %% [markdown]
# As early we have seen the boxplot using mathplot library its similar to that but colorful.

# %% [markdown]
# ## Correlation - Heatmap
#
# **`What is an Heatmap.`**
# A heatmap is a two-dimensional graphical representation of data where the individual values that are contained in a matrix are represented as colors. The seaborn python package allows the creation of annotated heatmaps which can be tweaked using Matplotlib tools as per the creator’s requirement.
#
#
# **`What/How do we interpret from the heat map.`**
# Each square shows the correlation between the variables on each axis. Correlation ranges from -1 to +1. Values closer to zero means there is no linear trend between the two variables. The close to 1 the correlation is the more positively correlated they are; that is as one increases so does the other and the closer to 1 the stronger this relationship is. A correlation closer to -1 is similar, but instead of both increasing one variable will decrease as the other increases.
#
#
# **`Correlation`:-**
# Correlation is a statistical measure that indicates the extent to which two or more variables fluctuate together. A positive correlation indicates the extent to which those variables increase or decrease in parallel; a negative correlation indicates the extent to which one variable increases as the other decreases.
#
# **`For Example`:-**
# **`Positive Correlation`**:-
# - The more time you spend running on a treadmill, the more calories you will burn.
# - When an employee works more hours his paycheck increases proportionately.
# - The more it rains, the more sales for umbrellas go up.
#
# **`Negative Correlation`**:-
# - If a car decreases speed, travel time to a destination increases.
#
# **`No Correlation`**:-
# - No correlation means that the two variables are not linked, not related, not connected in any way. Neither positive nor
#   negative.
#
#   `example`:-eating cheetos does not make you better at speaking Tamil. They are not related, there is no correlation.

# %%
print(df_train.head())
corrmat = df_train.corr()
f, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(corrmat, square=True);
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2008
# 1         Lvl    AllPub  ...    NaN   NaN         NaN       0      5   2007
# 2         Lvl    AllPub  ...    NaN   NaN         NaN       0      9   2008
# 3         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2006
# 4         Lvl    AllPub  ...    NaN   NaN         NaN       0     12   2008
#
#   SaleType  SaleCondition  SalePrice  SalePriceSF
# ...

# %%
import numpy as np;np.random.seed(0)
import seaborn as sns; sns.set()
data = np.random.randint(0,10,(10,10))
sns.heatmap(data)
print(data)
# Out:
# [[5 0 3 3 7 9 3 5 2 4]
#  [7 6 8 8 1 6 7 7 8 1]
#  [5 9 8 9 4 3 0 3 5 0]
#  [2 3 8 1 3 3 3 7 0 1]
#  [9 9 0 4 7 3 2 7 2 0]
#  [0 4 5 5 6 8 4 1 4 9]
#  [8 1 1 7 9 9 3 6 7 2]
#  [0 3 5 9 4 4 6 4 4 3]
#  [4 4 8 4 3 7 5 5 0 1]
#  [5 9 3 0 5 0 1 2 4 2]]

# %%
df_train.dtypes!=object
# Out:
# Id                True
# MSSubClass        True
# MSZoning         False
# LotFrontage       True
# LotArea           True
# Street           False
# Alley            False
# LotShape         False
# LandContour      False
# Utilities        False
# LotConfig        False
# LandSlope        False
# Neighborhood     False
# Condition1       False
# Condition2       False
# BldgType         False
# HouseStyle       False
# OverallQual       True
# OverallCond       True
# YearBuilt         True
# YearRemodAdd      True
# RoofStyle        False
# RoofMatl         False
# Exterior1st      False
# Exterior2nd      False
# MasVnrType       False
# MasVnrArea        True
# ExterQual        False
# ExterCond        False
# Foundation       False
#                  ...
# KitchenAbvGr      True
# KitchenQual      False
# TotRmsAbvGrd      True
# Functional       False
# Fireplaces        True
# FireplaceQu      False
# GarageType       False
# GarageYrBlt       True
# GarageFinish     False
# ...

# %% [markdown]
# we intrepret from the above plot/map that the darker the color the higher the correlation between the two variables. The plot is also symmetrical about the diagonal since the same two variables are being paired together in those squares.
#
# we can observe that few square box's are dark mean higher the co-relation between that variable/columns.

# %%
np.corrcoef(df_train["SalePrice"].values, df_train.SalePrice.values)
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %% [markdown]
# ## Plotting correlations

# %%
# plotting heat map as per the correlation between variables using matplotlib.
num_feat=df_train.columns[df_train.dtypes!=object]
num_feat=num_feat[1:-1] 
print(num_feat)
labels = []
values = []
for col in num_feat:
    labels.append(col)
    values.append(np.corrcoef(df_train[col].values, df_train.SalePrice.values)[0,1])
    
ind = np.arange(len(labels))
width = 0.1
fig, ax = plt.subplots(figsize=(12,40))
rects = ax.barh(ind, np.array(values), color='red')
ax.set_yticks(ind+((width)/2.))
#ax.set_yticklabels(labels)# rotation='horizontal')
ax.set_xlabel("Correlation coefficient")
ax.set_title("Correlation Coefficients w.r.t Sale Price");
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# we can observe that how much do the individual attribute/column correlate to the **sales price**.positve,negative,no correlation with my dependent/saleprice variable.
#
# **Highest positive co-relation of `salesprice` with -`Overall Qual`,`GrlivArea`,`Garage car`.**
#
# **Highest negative co-relation of `salesprice` with -`KitchenAbvGr`,`Enclosed porch`.**
#
# **No Co-relation with `salesprice` with `GarageYrBuilt`.**

# %% [markdown]
# ## Distplot (Distribution plot) .
#
# **what is an distplot.**
#
# The most convenient way to take a quick look at a distribution in seaborn is the distplot() function. By default, this will draw a histogram and fit a kernel density estimate (KDE).

# %%
sns.distplot(df_train['SalePrice'],bins=10,kde=True);   #this is an histogram representation of distribution of values and bin size sets the size of individual bin.

# %% [markdown]
# We can intrepret from the above plot that in the saleprice distribution where the mostly purchased house was around 15 lakhs.

# %% [markdown]
# **Rugplot/distplot**:-Histograms are likely familiar, and a hist function already exists in matplotlib. A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.let’s remove the density curve and add a rug plot, which draws a small vertical tick at each observation. You can make the rug plot itself with the rugplot() function, but it is also available in distplot()

# %%
sns.distplot(df_train['SalePrice'],bins=50,kde=True,rug=True);

# %% [markdown]
# From the above plot we can interpret that the houses where purchased by the customers w priced ranging between 1lakh to 3 lakh

# %% [markdown]
# ## Pair plot
#
# To plot multiple pairwise distributions in a dataset, you can use the pairplot() function. This creates a matrix of axes and shows the relationship for each pair of columns in a DataFrame. by default, it also draws the distribution of each variable on the diagonal Axes:

# %%
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df_train[cols], size = 2.5)
plt.show();

# %% [markdown]
# # Additional plot that can used for visulization

# %% [markdown]
# ## Regression Plot
# **Two main functions in seaborn are used to visualize a linear relationship as determined through regression**.
#
# These functions, regplot() and lmplot() are closely related, and share much of their core functionality. It is important to understand the ways they differ, however, so that you can quickly choose the correct tool for particular job.
# In the simplest invocation, both functions draw a scatterplot of two variables, x and y, and then fit the regression model y ~ x and plot the resulting regression line and a 95% confidence interval for that regression:

# %%
sns.regplot(data=df_train,
            y="SalePrice",
            x="YearBuilt",
            marker='*',
           color='r')

# Display the plot
plt.show()

# %%
sns.lmplot(data=df_train,
            x="YearBuilt",
            y="SalePrice")

# Display the plot
plt.show()

# %% [markdown]
# **regplot() performs a simple linear regression model fit and plot. lmplot() combines regplot() and FacetGrid.**
#
# **The FacetGrid class helps in visualizing the distribution of one variable as well as the relationship between multiple variables separately within subsets of your dataset using multiple panels.**
#
# **lmplot() is more computationally intensive and is intended as a convenient interface to fit regression models across conditional subsets of a dataset.**

# %% [markdown]
# ## Strip Plot
# **what is an strip plot and where it can be used.**
#
# Drawing/plotting a scatterplot where one variable is categorical.
# A strip plot can be drawn on its own, but it is also a good complement to a box plot in cases where you want to show all observations along with some representation of the underlying distribution.

# %%
sns.stripplot(data=df_train,
              x='SaleCondition',
              y='YearBuilt',
              jitter=True)

plt.show()

# %% [markdown]
# ## Swarm plot
#
# **What is swarm plot and where it can be used.**
#
# Swarm plot used for Drawing/plotting a categorical scatterplot with non-overlapping points.
# This function is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, but it does not scale well to large numbers of observations. This style of plot is sometimes called a “beeswarm”.

# %%
plt.scatter(df_train.SaleCondition, df_train.SalePrice)
plt.show()
sns.swarmplot(x='SaleCondition',y='SalePrice',data=df_train)
plt.show()
sns.swarmplot(x='SaleCondition',y='YearBuilt',data=df_train)

# %% [markdown]
# ## Point Plot
#
# **what is the purpose of point plot and where to be used.**
#
# A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.
#
# Point plots can be more useful than bar plots for focusing comparisons between different levels of one or more categorical variables. They are particularly adept at showing interactions: how the relationship between levels of one categorical variable changes across levels of a second categorical variable.

# %%
sns.pointplot(x="Fireplaces",y="SalePrice",data=df_train,hue="FireplaceQu")

plt.show()
plt.clf()

# %% [markdown]
# we can interpret from plot that as increase in number of fireplaces there is an subsequent increase in sales price

# %% [markdown]
# ## Joint Plot.
#
# The most familiar way to visualize a distribution is a scatterplot, where each observation is shown with point at the x and y values. This is analgous to a rug plot on two dimensions. You can draw a scatterplot with the matplotlib plt.scatter function, and it is also the default kind of plot shown by the jointplot() function:

# %%
sns.jointplot(df_train['LotFrontage'],df_train['LotArea'],color='gold');

# %% [markdown]
# we can intrepret from above plot that as the increase in `Lotfrontage` there is an increase in `Lotarea`.

# %%
plt.scatter(df_train["MasVnrArea"],df_train["SalePrice"])
plt.title("MasVnrArea Vs SalePrice ")
plt.ylabel("SalePrice")
plt.xlabel("Mas Vnr Area in sq feet");

# %% [markdown]
# we can interpret from the above plot that all the time as the increase in  Masonry veneer area in square feet there is no mandatory that where will be an increase in salesprice

# %% [markdown]
# ## Basement variable

# %%
plt.scatter(df_train["TotalBsmtSF"],df_train["SalePrice"])
plt.title("TotalBsmtSF Vs SalePrice ")
plt.ylabel("SalePrice")
plt.xlabel("TotalBsmtSF");

# %% [markdown]
# ## Factorplot
#
# **what is the purpose of factor plot and where to be used.**
#
# A Factor plot is similar to point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.
#
# Factor plots can be more useful than bar plots for focusing comparisons between different levels of one or more categorical variables. They are particularly adept at showing interactions: how the relationship between levels of one categorical variable changes across levels of a second categorical variable.

# %%
sns.factorplot("Fireplaces","SalePrice",data=df_train,hue="FireplaceQu");

# %% [markdown]
# In the above example, prices increase with quality and number of fireplaces

# %% [markdown]
# ## Does amount of 1st floor area help in sales price prediction ?

# %%
plt.scatter(df_train["1stFlrSF"],df_train.SalePrice, color='red')
plt.title("Sale Price wrt 1st floor")
plt.ylabel('Sale Price (in dollars)')
plt.xlabel("1st Floor in square feet");

# %% [markdown]
# As per our question above ,yes as increase in the first floor area there is an increase in saleprice

# %% [markdown]
# ## Create a new variables - sales price per sq ft

# %%
df_train['SalePriceSF'] = df_train['SalePrice']/df_train['GrLivArea']
plt.hist(df_train['SalePriceSF'], bins=15,color="gold")
plt.title("Sale Price per Square Foot")
plt.ylabel('Number of Sales')
plt.xlabel('Price per square feet');

# %% [markdown]
# ----------------------

# %% [markdown]
# # --------------------------------- HAPPY LEARNING ----------------------------------------------

# %% [markdown]
# --------------
