# %% [markdown]
# # 1.1 Creating Series:

# %% [markdown]
# # 1.1 Creating Series:

# %% [markdown]
# # 1.2 Accessing Series:

# %% [markdown]
# # 1.3 Modifying the data:

# %% [markdown]
# # 1.1 Creating Series:

# %% [markdown]
# # 1.1 Creating Series:

# %%
import pandas as pd
bowlers = {'Bhuvneshwar Kumar':[8.1,1,30,1,0,0,3.67],'Jasprit Bumrah':[8,1,25,1,0,0,3.13],'Hardik Pandya':[10,0,55,1,0,5,5.50]}
df1 = pd.DataFrame(data=bowlers) 
df1 = pd.DataFrame(data=bowlers,index=["O","M","R","W","NB","WD","Economy"])

# %%
df1.plot()

# %%
df1.T.plot()
df1.plot()
